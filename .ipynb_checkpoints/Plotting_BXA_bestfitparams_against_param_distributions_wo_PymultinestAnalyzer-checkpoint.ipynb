# %% [markdown]
# This file holds the results from the bxa fitting process.  It holds the best fit parameters based on the Multinest algorithm use of the Maximum Likelihood.  Holds best fit parameters, errors, and statistics.

# %% [markdown]
# For the 'PARAM' lists, the values are as in the following order:
#     - best-fit parameter
#     - 1-sigma lower
#     - 1-sigma upper
#     - 2-sigma lower
#     - 2-sigma upper
#     - 3-sigma lower
#     - 3-sigma upper

# %%
from __future__ import division
import os
import numpy 
import pandas as pd
from collections import OrderedDict
from astropy.io import fits as pyfits
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def check_exists(filename):
    if os.path.exists(filename):
        pass
    else:
        raise Exception, "File does not exist."

# %%
modName      = 'grbm+bbody+lpow'
version      = '-01-'
det          = 'L'
burst        = 'bn080916009'



# *_*_*_*_*_*_*_*_*_*_*_* DON'T CHANGE BELOW THIS LINE *_*_*_*_*_*_*_*_*_*_*_*

prefix       = '%s_%s_%s_'%(modName, version, det)
detdir       = ('GBMwLAT' if 'L' in det else 'GBM')

data_dir     = "/Users/KimiZ/GRBs2/analysis/LAT/%s/integrated/"%burst
mod_dir      = "/Users/KimiZ/GRBs2/analysis/LAT/%s/BXA/%s/%s/"%(burst, detdir, modName)



# BXA BEST FIT PARAMETER VALUES.
filename_1 = os.path.join(mod_dir, "%s.txt"%prefix)

# BXA PARAMETER DISTRIBUTION
filename_2 = os.path.join(mod_dir, "%schain.fits"%prefix)

# BXA MARGINALS AND STATS
filename_3 = os.path.join(mod_dir, "%sstats.json"%prefix)

# %% [markdown]
# ### TECHNICALLY, YOU DON'T NEED TO LOAD ALL THESE DIFFERENT FILES. YOU CAN JUST LAUNCH THE BXA PROGRAM AND GIVE THE PREFIX TO PYMULTINEST'S ANALYZER. THIS WILL GIVE YOU ACCESS TO THE DESIRED DATA.

# %%
for fileN in [filename_1, filename_2, filename_3]:
    check_exists(fileN)

# %%
f2     = pyfits.open(filename_2)
Pars   = f2[1].data.columns.names[:-1]  # LAST ONE IS FIT_STATISTIC
nPars  = len(Pars)

# %%
data2      = pd.DataFrame()
for n,name in enumerate(f2[1].data.columns.names):
    data2[name]   = f2[1].data[name]
    
data2   = data2.astype('float64')

# WILL SEND VALUES TO THE PLOTTING FUNCTION
values  = numpy.array(data2[:][:])

# %% [markdown]
# stats = stats_dict

# %%
stats_dict = json.load(open(filename_3, 'r'))

# %%
stats_dict
# Out:
# {u'global evidence': -173.20254697190333,
#  u'global evidence error': 0.02180615438177147,
#  u'marginals': [{u'1sigma': [-1.2590444138928065, -1.1973649549559815],
#    u'2sigma': [-1.280163373441964, -1.1579052895486976],
#    u'3sigma': [-1.2967128539422625, -1.0216419746977405],
#    u'5sigma': [-1.3071499595685971, -0.8572533025866627],
#    u'median': -1.2305908940362758,
#    u'q01%': -1.287853683867274,
#    u'q10%': -1.265534804893389,
#    u'q25%': -1.2497768383457009,
#    u'q75%': -1.2091330440350256,
#    u'q90%': -1.140308675325985,
#    u'q99%': -1.140308675325985,
#    u'sigma': 0.030839729468412513},
#   {u'1sigma': [-2.248187900052236, -2.206692838141549],
#    u'2sigma': [-2.2657098761963517, -2.186556855255446],
#    u'3sigma': [-2.28226290739736, -2.1670962364687862],
#    u'5sigma': [-2.293892966287687, -2.139534387950079],
#    u'median': -2.2276633713583127,
#    u'q01%': -2.271881641056847,
#    u'q10%': -2.2538203091833524,
#    u'q25%': -2.242071118910183,
#    u'q75%': -2.2132888943976647,
#    u'q90%': -2.179172344034993,
#    u'q99%': -2.179172344034993,
#    u'sigma': 0.02074753095534354},
#   {u'1sigma': [1033.5272356635305, 1481.3530239300617],
#    u'2sigma': [841.1614066824656, 1671.53744644116],
#    u'3sigma': [517.211158331582, 1886.467988624057],
#    u'5sigma': [338.0632083658058, 2111.0029132721884],
#    u'median': 1255.8557529862542,
#    u'q01%': 775.0708937980454,
#    u'q10%': 975.448277569186,
#    u'q25%': 1104.5575101094428,
#    u'q75%': 1409.5667454021395,
#    u'q90%': 1748.706742869052,
#    u'q99%': 1748.706742869052,
#    u'sigma': 223.91289413326558},
#   {u'1sigma': [-1.9371985528216595, -1.8914371647862724],
#    u'2sigma': [-1.9532706598083278, -1.861147360265559],
#    u'3sigma': [-1.967166971055885, -1.7567051299459857],
#    u'5sigma': [-1.9900323735412253, -1.7014560801109306],
#    u'median': -1.91660914193798,
#    u'q01%': -1.9582385471152726,
#    u'q10%': -1.9420370018121456,
#    u'q25%': -1.9306721846250405,
#    u'q75%': -1.900097875993342,
#    u'q90%': -1.8465915664813866,
#    u'q99%': -1.8465915664813866,
#    u'sigma': 0.022880694017693548},
#   {u'1sigma': [46.06813381707228, 51.44385391017079],
#    u'2sigma': [43.51711435000051, 54.71707438601367],
#    u'3sigma': [39.90837415671326, 65.31130676186083],
#    u'5sigma': [0.6017206585131392, 199.8591359459086],
#    u'median': 48.70567572616931,
#    u'q01%': 42.44015278328629,
#    u'q10%': 45.22574175725654,
#    u'q25%': 46.91100549242869,
#    u'q75%': 50.58206600198266,
#    u'q90%': 56.386581272379935,
#    u'q99%': 56.386581272379935,
#    u'sigma': 2.687860046549254},
#   {u'1sigma': [0.16878537529222734, 0.3107191133891433],
#    u'2sigma': [0.056248100666042515, 0.3591900732509806],
#    u'3sigma': [-4.449725843787982, 0.40111803642347565],
#    u'5sigma': [-14.992403529079004, 0.4452301842549337],
#    u'median': 0.24635734925188488,
#    u'q01%': -0.007933508924374784,
#    u'q10%': 0.14227024242360012,
#    u'q25%': 0.19542664789407577,
#    u'q75%': 0.291244758561511,
#    u'q90%': 0.37518030387919665,
#    u'q99%': 0.37518030387919665,
#    u'sigma': 0.07096686904845799},
#   {u'1sigma': [-3.2329827672264058, -0.6086909256743794],
#    u'2sigma': [-3.8528730204458066, 0.10496439015709821],
#    u'3sigma': [-3.9896234911369346, 0.43819776529791554],
#    u'5sigma': [-3.99974462692069, 0.5915489607544713],
#    u'median': -1.9447515184170416,
#    u'q01%': -3.934272776581156,
#    u'q10%': -3.4688860057396216,
#    u'q25%': -2.9033292462931453,
#    u'q75%': -0.9794053107417091,
#    u'q90%': 0.2521499972224038,
#    u'q99%': 0.2521499972224038,
#    u'sigma': 1.312145920776013},
#   {u'1sigma': [-13.515506658624934, -7.209822798569414],
#    u'2sigma': [-14.729212872371008, -4.948651163614674],
#    u'3sigma': [-14.984706991752446, -3.888764330528643],
#    u'5sigma': [-14.999747684038438, -3.370282816193503],
#    u'median': -10.795363181387216,
#    u'q01%': -14.877205331937114,
#    u'q10%': -13.995536979422207,
#    u'q25%': -12.814056571758874,
#    u'q75%': -8.375401361345896,
#    u'q90%': -4.538557854799251,
#    u'q99%': -4.538557854799251,
#    u'sigma': 3.15284193002776}],
#  u'modes': [{u'index': 0,
#    u'local log-evidence': -173.20254697190333,
#    u'local log-evidence error': 0.02180615438177147,
#    u'maximum': [-1.2444073390245496,
#     -2.2336080359707324,
#     1361.3537347606841,
#     -1.9270935297588672,
#     49.745294862872676,
#     0.28770963570415375,
#     0.031223134995272517,
#     -12.826868731590027],
#    u'maximum a posterior': [-1.2444073390245496,
#     -2.2336080359707324,
#     1361.3537347606841,
#     -1.9270935297588672,
#     49.745294862872676,
#     0.28770963570415375,
#     0.031223134995272517,
#     -12.826868731590027],
#    u'mean': [-1.2275409486287348,
#     -2.22737273959126,
#     1256.3773886007439,
#     -1.9140755939507015,
#     48.885003268693325,
#     0.2240326230365327,
#     -1.9250791489507182,
#     -10.470857365196089],
#    u'sigma': [0.032717722654856264,
#     0.020410412204759656,
#     217.79324740942508,
#     0.024298263502103127,
#     4.315944532357586,
#     0.3775199788215505,
#     1.1457948446266668,
#     2.7876987068232535],
#    u'strictly local log-evidence': -173.20254697190333,
#    u'strictly local log-evidence error': 0.02180615438177147}],
#  u'nested importance sampling global log-evidence': -173.20254697190333,
#  u'nested importance sampling global log-evidence error': 0.02180615438177147,
#  u'nested sampling global log-evidence': -173.28684079202134,
#  u'nested sampling global log-evidence error': 0.19330433053640803}

# %%
def marginal_plots(stats, parameters, n_params, values):
    s      = stats            # stats_dict, dictionary from stats.json file.
    modes  = s['modes']

    for i in range(n_params):
        plt.figure(figsize=(7,5))
        plt.xlabel(parameters[i])

        m = s['marginals'][i]
        plt.xlim(m['5sigma'])

        oldax = plt.gca()
        
        if 'norm' in parameters[i]:
            x,w,patches = oldax.hist(numpy.log10(values[:,i]), bins=20, 
                                     edgecolor='grey', color='grey', 
                                     histtype='stepfilled', alpha=0.2)
        else:
            x,w,patches = oldax.hist(values[:,i], bins=20, 
                                     edgecolor='grey', color='grey', 
                                     histtype='stepfilled', alpha=0.2)
        oldax.set_ylim(0, x.max())

        newax = plt.gcf().add_axes(oldax.get_position(), sharex=oldax, frameon=False)
        newax.set_ylim(0, 1)

        ylim = newax.get_ylim()
        y = ylim[0] + 0.05*(ylim[1] - ylim[0])
        center = m['median']
        low1, high1 = m['1sigma']
        newax.errorbar(x=center, y=y,
            xerr=numpy.transpose([[center - low1, high1 - center]]), 
            color='blue', linewidth=2, marker='s')
        
        newax.vlines(center, 0, 1, linestyle='--', color='blue', lw=1, label="%f"%center)
        bestFit = s['modes'][0]['maximum'][i]
        newax.vlines(bestFit, 0, 1, linestyle='--', color='black', lw=1, label="%f"%bestFit)
        
        oldax.set_yticks([])
        newax.set_ylabel("Probability")
        ylim = oldax.get_ylim()
        newax.set_xlim(m['5sigma'])
        oldax.set_xlim(m['5sigma'])
        #plt.legend(loc='best')
        plt.legend(loc=9)
        plt.show()

#plt.tight_layout() # kz keep axes from overlapping
#plt.savefig(prefix + 'marg.pdf')
#plt.savefig(prefix + 'marg.png')
#plt.close()

# %%
marginal_plots(stats_dict, Pars, nPars, values)

# %%
pwd
# Out:
# u'/Users/KimiZ/Python/Github/Research'

# %%
def marginal_plots_3sigma(stats, parameters, n_params, values):
    s = stats            # stats_dict, dictionary from stats.json file.
    n_params = n_params # nPars
    values = values    # array of the data from the chain.fits file. Parameter distributions. np.array(data2[:][:])
    modes = s['modes']

    #plt.figure(figsize=(5*n_params, 5*n_params))
    for i in range(n_params):
        plt.figure(figsize=(9,5))
        #plt.subplot(n_params, n_params, i + 1)
        plt.xlabel(parameters[i])

        m = s['marginals'][i]
        plt.xlim(m['3sigma'])

        oldax = plt.gca()
        
        if 'norm' in parameters[i]:
            x,w,patches = oldax.hist(numpy.log10(values[:,i]), bins=20, 
                                     edgecolor='grey', color='grey', 
                                     histtype='stepfilled', alpha=0.2)
        else:
            x,w,patches = oldax.hist(values[:,i], bins=20, 
                                     edgecolor='grey', color='grey', 
                                     histtype='stepfilled', alpha=0.2)
        oldax.set_ylim(0, x.max())

        newax = plt.gcf().add_axes(oldax.get_position(), sharex=oldax, frameon=False)
        #p.plot_marginal(i, ls='-', color='blue', linewidth=3)
        newax.set_ylim(0, 1)

        ylim = newax.get_ylim()
        y = ylim[0] + 0.05*(ylim[1] - ylim[0])
        center = m['median']
        low1, high1 = m['1sigma']
        #print center, low1, high1
        newax.errorbar(x=center, y=y,
            xerr=numpy.transpose([[center - low1, high1 - center]]), 
            color='blue', linewidth=2, marker='s')
        
        newax.vlines(center, 0, 1, linestyle='--', color='blue', lw=1, label="%f"%center)
        bestFit = s['modes'][0]['maximum'][i]
        newax.vlines(bestFit, 0, 1, linestyle='--', color='black', lw=1, label="%f"%bestFit)
        
        oldax.set_yticks([])
        #newax.set_yticks([])
        newax.set_ylabel("Probability")
        ylim = oldax.get_ylim()
        newax.set_xlim(m['3sigma'])
        oldax.set_xlim(m['3sigma'])
        #plt.legend(loc='best')
        plt.legend(loc=9)
        plt.show()

#plt.tight_layout() # kz keep axes from overlapping
#plt.savefig(prefix + 'marg.pdf')
#plt.savefig(prefix + 'marg.png')
#plt.close()

# %%
marginal_plots_3sigma(stats_dict, Pars, nPars, values)

# %% [raw]
# def marginal_plots(stats, parameters, n_params, values):
#     s = stats            # stats_dict, dictionary from stats.json file.
#     n_params = n_params # nPars
#     values = values    # array of the data from the chain.fits file. Parameter distributions. np.array(data2[:][:])
#     modes = s['modes']
#
#     #plt.figure(figsize=(5*n_params, 5*n_params))
#     for i in range(n_params):
#         #plt.subplot(n_params, n_params, i + 1)
#         plt.xlabel(parameters[i])
#
#         m = s['marginals'][i]
#         plt.xlim(m['5sigma'])
#
#         oldax = plt.gca()
#
#         if 'norm' in parameters[i]:
#             x,w,patches = oldax.hist(numpy.log10(values[:,i]), bins=20, edgecolor='grey', color='grey', histtype='stepfilled', alpha=0.2)
#         else:
#             x,w,patches = oldax.hist(values[:,i], bins=20, edgecolor='grey', color='grey', histtype='stepfilled', alpha=0.2)
#         oldax.set_ylim(0, x.max())
#
#         newax = plt.gcf().add_axes(oldax.get_position(), sharex=oldax, frameon=False)
#         #p.plot_marginal(i, ls='-', color='blue', linewidth=3)
#         newax.set_ylim(0, 1)
#
#         ylim = newax.get_ylim()
#         y = ylim[0] + 0.05*(ylim[1] - ylim[0])
#         center = m['median']
#         low1, high1 = m['1sigma']
#         #print center, low1, high1
#         newax.errorbar(x=center, y=y,
#             xerr=numpy.transpose([[center - low1, high1 - center]]),
#             color='blue', linewidth=2, marker='s')
#
#         bestFit = s['modes'][0]['maximum'][i]
#         newax.vlines(bestFit, 0, 1, linestyle='--', color='green', lw=1, label="%f"%bestFit)
#         oldax.set_yticks([])
#         #newax.set_yticks([])
#         newax.set_ylabel("Probability")
#         ylim = oldax.get_ylim()
#         newax.set_xlim(m['5sigma'])
#         oldax.set_xlim(m['5sigma'])
#         #newax.tight_layout() # kz keep axes from overlapping
#         #plt.close()
#         #plt.legend(loc='best')
#         plt.legend(loc=9)
#         plt.show()
#
#         # for j in range(i):
#         #     plt.subplot(n_params, n_params, n_params * (j + 1) + i + 1)
#         #     #p.plot_conditional(i, j, bins=20, cmap = plt.cm.gray_r)
#         #     for m in modes:
#         #         plt.errorbar(x=m['mean'][i], y=m['mean'][j], xerr=m['sigma'][i], yerr=m['sigma'][j])
#         #     plt.xlabel(parameters[i])
#         #     plt.ylabel(parameters[j])
#         #     plt.xlim(s['marginals'][i]['5sigma'])
#         #     plt.ylim(s['marginals'][j]['5sigma'])
#         #     plt.show()
#         #plt.savefig('cond_%s_%s.pdf' % (params[i], params[j]), bbox_tight=True)
#         #plt.close()
#     #plt.tight_layout() # kz keep axes from overlapping
#     #plt.savefig(prefix + 'marg.pdf')
#     #plt.savefig(prefix + 'marg.png')
#     #plt.close()

# %% [raw]
# def marginal_plots(stats, parameters, n_params, values):
#     s = stats            # stats_dict, dictionary from stats.json file.
#     n_params = n_params # nPars
#     values = values  # array of the data from the chain.fits file. Parameter distributions. np.array(data2[:][:])
#     modes = s['modes']
#
#     plt.figure(figsize=(5*n_params, 5*n_params))
#     for i in range(n_params):
#         plt.subplot(n_params, n_params, i + 1)
#         plt.xlabel(parameters[i])
#
#         m = s['marginals'][i]
#         plt.xlim(m['5sigma'])
#
#         oldax = plt.gca()
#         x,w,patches = oldax.hist(values[:,i], bins=20, edgecolor='grey', color='grey', histtype='stepfilled', alpha=0.2)
#         oldax.set_ylim(0, x.max())
#
#         newax = plt.gcf().add_axes(oldax.get_position(), sharex=oldax, frameon=False)
#         #p.plot_marginal(i, ls='-', color='blue', linewidth=3)
#         newax.set_ylim(0, 1)
#
#         ylim = newax.get_ylim()
#         y = ylim[0] + 0.05*(ylim[1] - ylim[0])
#         center = m['median']
#         low1, high1 = m['1sigma']
#         #print center, low1, high1
#         newax.errorbar(x=center, y=y,
#             xerr=numpy.transpose([[center - low1, high1 - center]]),
#             color='blue', linewidth=2, marker='s')
#
#         bestFit = s['modes'][0]['maximum'][i]
#         newax.vlines(bestFit, 0, 1, linestyle='--', color='green', lw=1)
#         oldax.set_yticks([])
#         #newax.set_yticks([])
#         newax.set_ylabel("Probability")
#         ylim = oldax.get_ylim()
#         newax.set_xlim(m['5sigma'])
#         oldax.set_xlim(m['5sigma'])
#         #plt.close()
#         plt.show()
#
#         # for j in range(i):
#         #     plt.subplot(n_params, n_params, n_params * (j + 1) + i + 1)
#         #     #p.plot_conditional(i, j, bins=20, cmap = plt.cm.gray_r)
#         #     for m in modes:
#         #         plt.errorbar(x=m['mean'][i], y=m['mean'][j], xerr=m['sigma'][i], yerr=m['sigma'][j])
#         #     plt.xlabel(parameters[i])
#         #     plt.ylabel(parameters[j])
#         #     plt.xlim(s['marginals'][i]['5sigma'])
#         #     plt.ylim(s['marginals'][j]['5sigma'])
#         #     plt.show()
#             #plt.savefig('cond_%s_%s.pdf' % (params[i], params[j]), bbox_tight=True)
#             #plt.close()
#     plt.tight_layout() # kz keep axes from overlapping
#     #plt.savefig(prefix + 'marg.pdf')
#     #plt.savefig(prefix + 'marg.png')
#     #plt.close()

# %% [raw]
# # DON'T NEED THIS BECAUSE ALL OF THE DATA HERE IS CONTAINED WITHIN THE
# # STATS.JSON FILE.  BUT WILL KEEP THIS ANYHOW.
#
# bestfit_values = OrderedDict()
# for i,name in enumerate(f1.data.columns.names):
#     if 'PARAM' in name:
#         Vals = list(f1.data[name][0])
#         bestfit_values["%s__%i"%(Pars[i],i+1)] = Vals
#     else:
#         if 'EVIDENCE' in name:
#             bestfit_values[name] = list(f1.data[name][0])
#         else:
#             bestfit_values[name] = f1.data[name][0]

# %% [raw]
# stats_dict = json.load(open(filename_3, 'r'))

# %% [raw]
# # OPEN FILES
# #f_1   = pyfits.open(filename_1)
# #f1 = f_1[1]

# %% [raw]
# # BXA BEST FIT PARAMETERS.
# filename_1 = os.path.join(mod_dir, "bxa_fitresults_%s_%s_%s_.fit"%(modName, version, det))
# # BXA PARAMETER DISTRIBUTION
# filename_2 = os.path.join(mod_dir, "%s_%s_%s_chain.fits"%(modName, version, det))
# # BXA MARGINALS AND STATS
# filename_3 = os.path.join(mod_dir, "%s_%s_%s_stats.json"%(modName, version, det))
